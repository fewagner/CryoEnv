# %%
import cryoenv.cryosig as cs
import numpy as np

# %%
det = cs.DetectorModel()

# %%
det.wait(5)

# %%
det.trigger(np.array([0.,0.]), np.array([1.]))
# Out:
# T0 is [31.26813539 39.37214759] mK.
# Calculated in 0.6796228885650635 s.
# Generated noise in 0.007665157318115234 s.

# %%
det.plot_tes()
